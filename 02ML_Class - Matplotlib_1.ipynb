# %% [markdown]
# # Matplotlib
#
# ## Visualization

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
xpoint = np.array([0,10])
ypoint = np.array([5,150])

plt.plot(xpoint, ypoint)
plt.show()

# %%
xpoint = np.array([3,5])
ypoint = np.array([2,7])

plt.plot(xpoint, ypoint)
plt.show()

# %%
xpoint = np.array([1,6])
ypoint = np.array([5,10])

plt.plot(xpoint, ypoint)
plt.show()

# %%
ypoint = np.array([4,5])

plt.plot(xpoint, ypoint, 'o')
plt.show()

# %%
ypoint = np.array([4,5])

plt.plot(xpoint, ypoint, marker = 'x')
plt.show()

# %%
ypoint = np.array([3,8,1,10])

plt.plot(ypoint, marker = 'x')
plt.show()

# %%
plt.plot(ypoint, marker = 'x')
plt.show()

# %%
plt.plot(ypoint, marker = '^')
plt.show()

# %%
ypoint = np.array([3,8,1,10])

plt.plot(ypoint, '^:y')  # o-dot , :-dotted, g-green
plt.show()

# %%
ypoint = np.array([3,8,1,10])

plt.plot(ypoint, marker = 'o', ms = 20)  
plt.show()

# %%
ypoint = np.array([3,8,1,10])

plt.plot(ypoint, marker = 'o', ms = 20, mec = 'r')  
plt.show()

# %%
ypoint = np.array([3,8,1,10])

plt.plot(ypoint, marker = 'o', ms = 20, mec = 'r', mfc = 'r')  
plt.show()

# %%
ypoint = np.array([3,8,1,10])

plt.plot(ypoint, marker = 'o', ms = 20, mec = 'k', mfc = 'r')  
plt.show()

# %%
ypoint = np.array([3,8,1,10])

plt.plot(ypoint, marker = 'o', ms = 20, mec = '#4CAF50', mfc = '#4CAF50')  
plt.show()

# %%
ypoint = np.array([3,8,1,10])

plt.plot(ypoint, marker = 'o', ms = 20, mec = 'hotpink', mfc = 'hotpink')  
plt.show()

# %%
ypoint = np.array([3,8,1,10])

plt.plot(ypoint, linestyle= 'dotted')  
plt.show()

# %%
ypoint = np.array([3,8,1,10])

plt.plot(ypoint, linestyle= 'dashed')  
plt.show()

# %%
ypoint = np.array([3,8,1,10])

plt.plot(ypoint, color = 'orange')  
plt.show()

# %%
ypoint = np.array([3,8,1,10])

plt.plot(ypoint, color = 'orange', linewidth = 15)  
plt.show()

# %%
y1 = np.array([3,8,1,10])
y2 = np.array([6,2,5,11])

plt.plot(y1, color = 'orange')  
plt.plot(y2, color = 'red')  

plt.show()

# %%
y1 = np.array([3,8,1,10])
y2 = np.array([6,2,5,11])

plt.plot(y1, y2)   

plt.show()

# %%
x1 = np.array([0,2,4,6])
y1 = np.array([3,8,1,10])
x2 = np.array([0,5,10,15])
y2 = np.array([6,2,7,11])

plt.plot(x1, y1, x2, y2, color = 'orange')   

plt.show()

# %%
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])

plt.subplot(2,4,1)
plt.plot(x,y)

x = np.array([0,1,2,3])
y = np.array([3,8,1,10])

plt.subplot(2,4,2)
plt.plot(x,y)

x = np.array([0,1,2,3])
y = np.array([3,8,9,10])

plt.subplot(2,4,3)
plt.plot(x,y)

x = np.array([0,1,2,3])
y = np.array([3,8,7,10])

plt.subplot(2,4,4)
plt.plot(x,y)

x = np.array([0,1,2,3])
y = np.array([3,8,1,10])

plt.subplot(2,4,5)
plt.plot(x,y)
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])

plt.subplot(2,4,6)
plt.plot(x,y)

x = np.array([0,1,2,3])
y = np.array([3,8,1,10])

plt.subplot(2,4,7)
plt.plot(x,y)

x = np.array([0,1,2,3])
y = np.array([3,8,1,10])

plt.subplot(2,4,8)
plt.plot(x,y)

plt.show()

# %%
#plot1
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])

plt.subplot(2,1,1)   
plt.plot(x,y) 

#plot2
x = np.array([0,1,2,3])
y = np.array([10,20,30,40])

plt.subplot(2,1,2)   
plt.plot(x,y)  

plt.show()

# %%
#plot1
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])

plt.subplot(2,2,1)   
plt.plot(x,y) 

#plot2
x = np.array([0,1,2,3])
y = np.array([10,20,30,40])

plt.subplot(2,2,2)   
plt.plot(x,y) 

#plot3
x = np.array([0,1,2,3])
y = np.array([10,20,30,40])

plt.subplot(2,2,3)   
plt.plot(x,y)

#plot4
x = np.array([0,1,2,3])
y = np.array([10,20,30,40])

plt.subplot(2,2,4)   
plt.plot(x,y)

plt.show()

# %%
#plot1
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])

plt.subplot(2,3,1)   
plt.plot(x,y) 

#plot2
x = np.array([0,1,2,3])
y = np.array([10,20,30,40])

plt.subplot(2,1,2)   
plt.plot(x,y) 

#plot3
x = np.array([0,1,2,3])
y = np.array([10,20,30,40])

plt.subplot(2,3,3)   
plt.plot(x,y)

plt.show()

# %%
#plot1
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])

plt.subplot(2,1,1)   
plt.plot(x,y) 
plt.title("Sample - 1")
plt.xlabel("Sales")


#plot2
x = np.array([0,1,2,3])
y = np.array([10,20,30,40])
plt.ylabel("Income")

plt.subplot(2,1,2)   
plt.plot(x,y) 

#plt.subtitle("My shop")
plt.show()

# %%
# Out:
# array([24,  3])
